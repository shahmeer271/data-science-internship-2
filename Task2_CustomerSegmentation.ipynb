# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ## 1. Introduction
# Segment customers based on Annual Income and Spending Score using K-Means clustering.

# %%
url = "https://raw.githubusercontent.com/vjchoudhary7/Customer-Segmentation-Tutorial-in-Python/master/Mall_Customers.csv"
df = pd.read_csv(url)
df.head()

# %% [markdown]
# ## 2. Exploratory Data Analysis
# Pairplot to see relationships.

# %%
sns.pairplot(df[['Age', 'Annual Income (k$)', 'Spending Score (1-100)']])
plt.show()

# %% [markdown]
# ## 3. Feature Selection and Scaling
# Using Annual Income and Spending Score. Scale them.

# %%
X = df[['Annual Income (k$)', 'Spending Score (1-100)']]
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %% [markdown]
# ## 4. Elbow Method
# Plot inertia for k=1 to 10.

# %%
inertia = []
for k in range(1,11):
    kmeans = KMeans(n_clusters=k, random_state=42, n_init=10)
    kmeans.fit(X_scaled)
    inertia.append(kmeans.inertia_)
plt.plot(range(1,11), inertia, marker='o')
plt.title('Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('Inertia')
plt.show()

# %% [markdown]
# ## 5. K-Means with 5 clusters
# Based on elbow, choose k=5.

# %%
kmeans = KMeans(n_clusters=5, random_state=42, n_init=10)
df['Cluster'] = kmeans.fit_predict(X_scaled)

# %% [markdown]
# ## 6. Cluster Visualization
# Scatter plot of Income vs Spending Score colored by cluster.

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(x='Annual Income (k$)', y='Spending Score (1-100)', hue='Cluster', data=df, palette='viridis')
plt.title('Customer Segments')
plt.show()

# %% [markdown]
# ## 7. PCA for 2D projection (optional)
# Reduce to 2 principal components and plot.

# %%
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)
plt.scatter(X_pca[:,0], X_pca[:,1], c=df['Cluster'], cmap='viridis')
plt.title('PCA Projection of Clusters')
plt.show()

# %% [markdown]
# ## 8. Marketing Strategies per Segment
# - Cluster 0 (High Income, Low Spending): Premium loyalty programs, exclusive offers.
# - Cluster 1 (Low Income, Low Spending): Discounts, basic products, cashback.
# - Cluster 2 (Medium Income, Medium Spending): Standard marketing, email campaigns.
# - Cluster 3 (High Income, High Spending): VIP events, personalized service.
# - Cluster 4 (Low Income, High Spending): Installment plans, buy-now-pay-later.
